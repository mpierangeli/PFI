# %%
import os
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
import cv2
from tensorflow import keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
import random
import matplotlib.pyplot as plt
from keras.metrics import MeanIoU
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda, Activation, MaxPool2D, Concatenate, add, multiply
from keras.optimizers import Adam
from keras import mixed_precision
from keras import backend as K
from keras.metrics import binary_crossentropy

# %%
keras.backend.clear_session()

# %%
is_gpu_available = (len(tf.config.list_physical_devices('GPU')) > 0)
print(is_gpu_available)

#mixed_precision.set_global_policy('mixed_float16')
#os.environ["TF_ENABLE_AUTO_MIXED_PRECISION_GRAPH_REWRITE"] = "1"
#os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'
# Out:
# True

# %%
fp1 = r"C:\Users\Pier\Desktop\PFI_main\DS_VOLUMEN\main\train_data"
fp2 = r"C:\Users\Pier\Desktop\PFI_main\DS_VOLUMEN\main\validation_data"

# %%
batch_size = 6

# %% [markdown]
# ---

# %%
def load_data(ids,suj_path,mask_path):
  suj_files = os.listdir(suj_path)
  mask_files = os.listdir(mask_path)
  X = []
  Y = []

  for i in ids:
    x = np.load(os.path.join(suj_path,suj_files[i]))
    y = np.load(os.path.join(mask_path,mask_files[i]))

    X.append(x)
    Y.append(y)

  return np.array(X), np.array(Y)

# %%
def batch_generator(suj_path, mask_path):
    suj_files = os.listdir(suj_path)
    indices = np.arange(len(suj_files))
    indices = np.random.permutation(indices)
    batch=[]
    while True:
            for i in indices:
                batch.append(i)
                if len(batch)==batch_size:
                    yield load_data(batch,suj_path,mask_path)
                    batch=[]

# %%
train_gen_ds = batch_generator(os.path.join(fp1,"sujetos"),os.path.join(fp1,"mascaras"))

val_gen_ds = batch_generator(os.path.join(fp2,"sujetos"),os.path.join(fp2,"mascaras"))

# %%
x,y = train_gen_ds.__next__()

# %%
print(x)
# Out:
# [[[ 1.12617843  1.25036742  1.35586296 ... -0.74390979 -0.80380642
#    -1.05637781]
#   [ 1.14859768  1.21307537  1.35809281 ... -0.89417766 -0.94678905
#    -1.29564423]
#   [ 1.11434361  1.01029927  1.31416036 ... -0.97497267 -1.07008431
#    -1.18126165]
#   ...
#   [-0.70628517 -0.58712589 -0.05049697 ... -0.78287348 -0.94636494
#    -0.9162653 ]
#   [-0.68043745 -0.93027518 -0.6643599  ... -1.05800925 -1.17487228
#    -1.2540153 ]
#   [-0.23543519 -0.48585508 -0.57359319 ... -1.21114163 -1.21235247
#    -1.26806742]]
#
#  [[-1.30125977 -1.27548956 -1.17707027 ... -1.09266103 -1.07918433
#    -1.1131928 ]
#   [-1.33310178 -1.30495257 -1.23596487 ... -1.16184837 -1.13436759
#    -1.19408994]
#   [-1.36495964 -1.3353847  -1.26927115 ... -1.13165864 -1.14200236
#    -1.17044964]
#   ...
#   [-1.32254469 -1.55726708 -1.66930246 ... -0.47618548 -0.61135103
#    -0.66142761]
#   [-1.24811949 -1.54574073 -1.59354586 ... -0.63963023 -0.5528425
#    -0.71937958]
#   [-1.30636441 -1.4853759  -1.47181744 ... -0.81498825 -0.77783629
#    -0.75448144]]
#
#  [[-0.31460117 -0.25237743 -0.46629359 ... -1.55859685 -1.49494573
#    -1.49379533]
#   [-0.43441202 -0.57295799 -0.75390399 ... -1.50688978 -1.63738364
#    -1.56573538]
#   [-0.61831176 -0.88525835 -1.00884926 ... -1.22580743 -1.35200502
#    -1.29911634]
#   ...
#   [-1.94745226 -2.00107417 -1.94105299 ... -1.53004184 -1.32449607
#    -1.31627793]
#   [-1.96253426 -1.7367296  -1.60037689 ... -1.58924057 -1.45094722
#    -1.54426927]
#   [-1.81687317 -1.70738927 -1.47705038 ... -1.69747604 -1.6663016
#    -1.68597803]]
#
#  [[-1.29511311 -1.30718608 -1.35782946 ... -0.74066464 -0.73001854
#    -0.9722453 ]
#   [-1.34182635 -1.32594736 -1.35826777 ... -0.87221761 -0.76989087
#    -0.968067  ]
#   [-1.37837279 -1.35364739 -1.34973443 ... -0.97353571 -0.81893593
#    -0.97094152]
#   ...
#   [-1.40919261 -1.39905926 -1.40387903 ... -1.25108837 -1.43851422
#    -1.28434789]
#   [-1.4122112  -1.39029018 -1.38627592 ... -1.11030087 -1.37967592
#    -1.46462985]
#   [-1.40685866 -1.37522318 -1.36932456 ... -0.87227832 -1.1588808
#    -1.50050619]]
#
#  [[-1.2029202  -1.18064431 -1.22680076 ...  1.20402353  1.30307622
#     1.31499244]
#   [-1.24722533 -1.20252034 -1.25964928 ...  1.34191748  1.34178683
#     1.26210619]
#   [-1.2467466  -1.17984938 -1.24909111 ...  1.31699553  1.2972717
#     1.33466196]
#   ...
#   [-0.63959964 -0.54350627 -0.60648623 ...  0.46910032 -0.07680949
#    -0.19990716]
#   [-0.67434791 -0.63365949 -0.63909903 ...  0.34348472  0.02509117
#     0.04449591]
#   [-0.69597838 -0.67950152 -0.69439141 ... -0.17155764 -0.29785669
#    -0.24193787]]
#
#  [[ 0.44879459 -0.13847127 -0.63889995 ... -1.04865553 -0.96461626
#    -0.75909845]
#   [ 0.78738571  0.22770134 -0.28123949 ... -1.35381824 -1.24064948
#    -1.04238853]
#   [ 1.00521925  0.52038707  0.08072696 ... -1.27110005 -1.15921705
#    -0.90248095]
#   ...
#   [-1.08230128 -1.13455273 -1.26097807 ... -1.39142233 -1.39142233
#    -1.2698937 ]
#   [-1.30551116 -1.21890201 -1.21758556 ... -1.38878909 -1.10122761
#    -0.39268435]
#   [-1.24995084 -1.19488265 -1.18249268 ... -0.90232392  0.01984578
#     1.15362818]]]

# %%
print(x.shape)
print(y.shape)
print(x.max(),x.min())
print(y.max(),y.min())
# Out:
# (6, 256, 256)
# (6, 256, 256)
# 2.9459618606391174 -2.1882256788680627
# 1.0 0.0

# %%
x,y = val_gen_ds.__next__()
image = x[0,:,:]
mask = y[0,:,:]
plt.subplot(1,2,1)
plt.imshow(image,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(mask,cmap="gray")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n_train_img = len(os.listdir(os.path.join(fp1,"sujetos"))) #si es para npy saco "img"
n_val_img = len(os.listdir(os.path.join(fp2,"sujetos")))
print(n_train_img,n_val_img)
spe = n_train_img//batch_size 
vspe = n_val_img//batch_size
# Out:
# 3971 826

# %% [markdown]
# ---

# %%
def conv_block(input, num_filters, NUM_CLASSES=1, dropout=0, batch_norm=False):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    #x = Dropout(0.15)(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    
    return x

def gating_signal(input, out_size, batch_norm=False):

    x = Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    theta_x = Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

    phi_g = Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = add([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)
    psi = Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = multiply([upsample_psi, x])

    result = Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = BatchNormalization()(result)
    
    return result_bn

def repeat_elem(tensor, rep):

    return Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': rep})(tensor)
     
def res_conv_block(x, filter_size, size, dropout=0, batch_norm=False):

    conv = Conv2D(size, (filter_size, filter_size), padding='same')(x)
    
    conv = BatchNormalization(axis=3)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    conv = BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    #conv = Dropout(dropout)(conv)

    shortcut = Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    shortcut = BatchNormalization(axis=3)(shortcut)

    res_path = add([shortcut, conv])
    res_path = Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    
    return res_path

# %%
def Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
  
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    
    inputs = Input(input_shape, dtype=tf.float32)


    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = MaxPooling2D(pool_size=(2,2))(conv_128)
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = MaxPooling2D(pool_size=(2,2))(conv_64)
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = MaxPooling2D(pool_size=(2,2))(conv_32)
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = MaxPooling2D(pool_size=(2,2))(conv_16)
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)


    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)

    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)

    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)

    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)


    conv_final = Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = BatchNormalization(axis=3)(conv_final)
    conv_final = Activation('sigmoid')(conv_final)  #Change to softmax for multichannel


    model = Model(inputs, conv_final, name="Attention_UNet")
    return model
my_att_unet = Attention_UNet(input_shape=(256,256,1))

# %%
print(my_att_unet.summary())

# %%
my_unet = UNet()
print(my_unet.summary())
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_106 (Conv2D)            (None, 256, 256, 3)  30          ['input_5[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 256, 256, 3)  12         ['conv2d_106[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 256, 256, 3)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 256, 256, 3)  84          ['activation_50[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 256, 256, 3)  12         ['conv2d_107[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 256, 256, 3)  0           ['batch_normalization_47[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 128, 128, 3)  0          ['activation_51[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 128, 128, 3)  84          ['max_pooling2d_16[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 3)  12         ['conv2d_108[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 128, 128, 3)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 128, 128, 3)  84          ['activation_52[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 3)  12         ['conv2d_109[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 128, 128, 3)  0           ['batch_normalization_49[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 64, 64, 3)   0           ['activation_53[0][0]']
#  )
#
#  conv2d_110 (Conv2D)            (None, 64, 64, 3)    84          ['max_pooling2d_17[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 3)   12          ['conv2d_110[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 64, 64, 3)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 64, 64, 3)    84          ['activation_54[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 3)   12          ['conv2d_111[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 64, 64, 3)    0           ['batch_normalization_51[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 32, 32, 3)   0           ['activation_55[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 32, 32, 3)    84          ['max_pooling2d_18[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 3)   12          ['conv2d_112[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 32, 32, 3)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 32, 32, 3)    84          ['activation_56[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 3)   12          ['conv2d_113[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 32, 32, 3)    0           ['batch_normalization_53[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 16, 16, 3)   0           ['activation_57[0][0]']
#  )
#
#  conv2d_114 (Conv2D)            (None, 16, 16, 3)    84          ['max_pooling2d_19[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 3)   12          ['conv2d_114[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 16, 16, 3)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 3)    84          ['activation_58[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 3)   12          ['conv2d_115[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 16, 16, 3)    0           ['batch_normalization_55[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 32, 32, 3)   0           ['activation_59[0][0]']
#  )
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 6)    0           ['up_sampling2d_20[0][0]',
#                                                                   'activation_57[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 32, 32, 3)    165         ['concatenate_16[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 3)   12          ['conv2d_116[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 32, 32, 3)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 32, 32, 3)    84          ['activation_60[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 3)   12          ['conv2d_117[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 32, 32, 3)    0           ['batch_normalization_57[0][0]']
#
#  up_sampling2d_21 (UpSampling2D  (None, 64, 64, 3)   0           ['activation_61[0][0]']
#  )
#
#  concatenate_17 (Concatenate)   (None, 64, 64, 6)    0           ['up_sampling2d_21[0][0]',
#                                                                   'activation_55[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 64, 64, 3)    165         ['concatenate_17[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 3)   12          ['conv2d_118[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 64, 64, 3)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 64, 64, 3)    84          ['activation_62[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 3)   12          ['conv2d_119[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 64, 64, 3)    0           ['batch_normalization_59[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 128, 128, 3)  0          ['activation_63[0][0]']
#  )
#
#  concatenate_18 (Concatenate)   (None, 128, 128, 6)  0           ['up_sampling2d_22[0][0]',
#                                                                   'activation_53[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 128, 128, 3)  165         ['concatenate_18[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 3)  12         ['conv2d_120[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 128, 128, 3)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 128, 128, 3)  84          ['activation_64[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 128, 128, 3)  12         ['conv2d_121[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 128, 128, 3)  0           ['batch_normalization_61[0][0]']
#
#  up_sampling2d_23 (UpSampling2D  (None, 256, 256, 3)  0          ['activation_65[0][0]']
#  )
#
#  concatenate_19 (Concatenate)   (None, 256, 256, 6)  0           ['up_sampling2d_23[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 256, 256, 3)  165         ['concatenate_19[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 256, 256, 3)  12         ['conv2d_122[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 256, 256, 3)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 256, 256, 3)  84          ['activation_66[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 256, 256, 3)  12         ['conv2d_123[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 256, 256, 3)  0           ['batch_normalization_63[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 256, 256, 1)  4           ['activation_67[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 256, 256, 1)  4          ['conv2d_124[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_64[0][0]']
#
# ==================================================================================================
# Total params: 2,006
# Trainable params: 1,896
# Non-trainable params: 110
# __________________________________________________________________________________________________
# None

# %%
def Attention_ResUNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Rsidual UNet, with attention 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    # input data
    # dimension of the image depth
    inputs = Input(input_shape, dtype=tf.float32)
    axis = 3

    # Downsampling layers
    # DownRes 1, double residual convolution + pooling
    conv_128 = res_conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = res_conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = res_conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = res_conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = res_conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = concatenate([up_16, att_16], axis=axis)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = concatenate([up_32, att_32], axis=axis)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = concatenate([up_64, att_64], axis=axis)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = concatenate([up_128, att_128], axis=axis)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    
    conv_final = Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = BatchNormalization(axis=axis)(conv_final)
    conv_final = Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = Model(inputs, conv_final, name="AttentionResUNet")
    return model

# %%
def DiceBCE(targets, inputs, smooth=1e-6):    
       
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    intersection = K.sum(targets * inputs)
    
    return (2*intersection + smooth) / (K.sum(targets) + K.sum(inputs) + smooth)

def Jaccard(targets, inputs, smooth=1e-6):
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)

    intersection = K.sum(K.abs(inputs * targets))
    union = K.sum(inputs) + K.sum(targets) - intersection
    
    return (intersection + smooth)/(union + smooth)

def DiceBCELoss(targets, inputs):    
    
    BCE =  binary_crossentropy(targets, inputs)
    
    return BCE + 1 - DiceBCE(targets, inputs, smooth=1e-2)

def FocalLoss(targets, inputs, alpha=0.8, gamma=2):
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    
    return alpha * K.pow((1-BCE_EXP), gamma) * BCE

# %%
# from skimage.measure import label, regionprops
# from scipy.spatial.distance import directed_hausdorff

# # Calculate the Hausdorff distance between two binary images
# def hausdorff_distance(y_true, y_pred):
#     # Extract the connected components from the images
#     true_labels = label(y_true)
#     pred_labels = label(y_pred)
    
#     # Convert the images to sets of points
#     true_points = [region.coords for region in regionprops(true_labels)]
#     pred_points = [region.coords for region in regionprops(pred_labels)]
    
#     # Calculate the directed Hausdorff distance between the sets of points
#     distance = directed_hausdorff(true_points, pred_points)[0]
    
#     return distance

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    initial_lr = 0.01
    decay = 0.95
    return initial_lr * decay ** epoch

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True,monitor="val_DiceBCE",mode="max"),
    tf.keras.callbacks.ModelCheckpoint(filepath='modelsh5/unet_model.{val_DiceBCE:.4f}_att_unet.h5',save_best_only=True,save_weights_only=True,monitor="val_DiceBCE",mode="max"),
    #tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_DiceBCE', mode="max", factor=0.5,patience=5, min_lr=0.00001,mind_delta=0.005)
    #tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
#optimizer = tf.keras.mixed_precision.LossScaleOptimizer(Adam(learning_rate = 1e-3))
optimizer = Adam(learning_rate = 1e-2)

# %%
#my_unet = keras.models.load_model("modelsh5/unet_model.00-0.0166-0.7759_base_focal_.h5",custom_objects={"DiceBCE":DiceBCE,"DiceBCELoss":DiceBCELoss,"FocalLoss":FocalLoss})

# %%
#my_unet.load_weights("modelsh5/unet_model.11-0.6497_base_focal_doff.h5")

# %%
my_att_unet.compile(optimizer = optimizer, loss = DiceBCELoss, metrics = [DiceBCE,Jaccard])

# %%
history = my_att_unet.fit(train_gen_ds,
                    verbose=1, 
                    steps_per_epoch=spe,
                    epochs=100,
                    validation_data=val_gen_ds, 
                    validation_steps=vspe,
                    callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 661/661 [==============================] - 48s 67ms/step - loss: 0.4619 - DiceBCE: 0.6214 - Jaccard: 0.4716 - val_loss: 0.9614 - val_DiceBCE: 0.4574 - val_Jaccard: 0.3159 - lr: 0.0100
# Epoch 2/100
# 661/661 [==============================] - 40s 60ms/step - loss: 0.4505 - DiceBCE: 0.6309 - Jaccard: 0.4815 - val_loss: 0.4223 - val_DiceBCE: 0.6623 - val_Jaccard: 0.5168 - lr: 0.0100
# Epoch 3/100
# 661/661 [==============================] - 40s 60ms/step - loss: 0.4591 - DiceBCE: 0.6225 - Jaccard: 0.4761 - val_loss: 0.5302 - val_DiceBCE: 0.5558 - val_Jaccard: 0.4154 - lr: 0.0100
# Epoch 4/100
# 661/661 [==============================] - 40s 60ms/step - loss: 0.4480 - DiceBCE: 0.6310 - Jaccard: 0.4850 - val_loss: 0.6101 - val_DiceBCE: 0.5581 - val_Jaccard: 0.4106 - lr: 0.0100
# Epoch 5/100
# 661/661 [==============================] - 40s 61ms/step - loss: 0.4485 - DiceBCE: 0.6311 - Jaccard: 0.4863 - val_loss: 0.3737 - val_DiceBCE: 0.7036 - val_Jaccard: 0.5630 - lr: 0.0100
# Epoch 6/100
# 661/661 [==============================] - 44s 67ms/step - loss: 0.4364 - DiceBCE: 0.6417 - Jaccard: 0.4951 - val_loss: 0.8665 - val_DiceBCE: 0.3010 - val_Jaccard: 0.1972 - lr: 0.0100
# Epoch 7/100
# 661/661 [==============================] - 45s 68ms/step - loss: 0.4300 - DiceBCE: 0.6474 - Jaccard: 0.5003 - val_loss: 0.4482 - val_DiceBCE: 0.6469 - val_Jaccard: 0.5034 - lr: 0.0100
# Epoch 8/100
# 661/661 [==============================] - 46s 69ms/step - loss: 0.4144 - DiceBCE: 0.6607 - Jaccard: 0.5149 - val_loss: 0.4768 - val_DiceBCE: 0.6288 - val_Jaccard: 0.4854 - lr: 0.0100
# Epoch 9/100
# 661/661 [==============================] - 45s 68ms/step - loss: 0.4303 - DiceBCE: 0.6461 - Jaccard: 0.5027 - val_loss: 0.5452 - val_DiceBCE: 0.6080 - val_Jaccard: 0.4667 - lr: 0.0100
# Epoch 10/100
# 661/661 [==============================] - 44s 67ms/step - loss: 0.4215 - DiceBCE: 0.6546 - Jaccard: 0.5122 - val_loss: 0.9940 - val_DiceBCE: 0.3567 - val_Jaccard: 0.2292 - lr: 0.0100
# Epoch 11/100
# 661/661 [==============================] - 44s 67ms/step - loss: 0.4056 - DiceBCE: 0.6642 - Jaccard: 0.5243 - val_loss: 0.4130 - val_DiceBCE: 0.6713 - val_Jaccard: 0.5307 - lr: 0.0050
# Epoch 12/100
# 661/661 [==============================] - 45s 68ms/step - loss: 0.3904 - DiceBCE: 0.6771 - Jaccard: 0.5362 - val_loss: 0.4641 - val_DiceBCE: 0.6347 - val_Jaccard: 0.5026 - lr: 0.0050
# Epoch 13/100
# 661/661 [==============================] - 45s 67ms/step - loss: 0.3792 - DiceBCE: 0.6863 - Jaccard: 0.5458 - val_loss: 1.5447 - val_DiceBCE: 0.2644 - val_Jaccard: 0.1593 - lr: 0.0050
# Epoch 14/100
# 661/661 [==============================] - 45s 68ms/step - loss: 0.3729 - DiceBCE: 0.6931 - Jaccard: 0.5532 - val_loss: 0.4209 - val_DiceBCE: 0.6679 - val_Jaccard: 0.5241 - lr: 0.0050
# Epoch 15/100
# 661/661 [==============================] - 45s 68ms/step - loss: 0.3852 - DiceBCE: 0.6803 - Jaccard: 0.5422 - val_loss: 9.7706 - val_DiceBCE: 0.1023 - val_Jaccard: 0.0550 - lr: 0.0050

# %%
history.history['val_DiceBCE']
# Out:
# [0.1157730221748352,
#  0.31176483631134033,
#  0.42073431611061096,
#  0.42082321643829346,
#  0.429561048746109,
#  0.5722036957740784,
#  0.5433778166770935,
#  0.563554048538208,
#  0.5505870580673218,
#  0.6473495364189148,
#  0.6497437953948975]

# %%
my_unet.save("modelsh5/unet_model.06-0.0000-0.8274_base_focal_.h5")

# %%
#my_unet.evaluate()

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['DiceBCE']
val_acc = history.history['val_DiceBCE']

plt.plot(epochs, acc, 'y', label='Training dice_score')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation dice_score')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

# %%
test_image_batch, test_mask_batch = val_gen_ds.__next__()
test_img_number = random.randint(0, len(test_image_batch)-1)
test_img = test_image_batch[test_img_number]
ground_truth=test_mask_batch[test_img_number]
test_img_norm=test_img[:,:]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (my_unet.predict(test_img_input))
predicted_img_th = prediction[0,:,:,0]>0.5

IOU_keras = MeanIoU(num_classes=2)  
IOU_keras.update_state(ground_truth, predicted_img_th)
print("Mean IoU =", IOU_keras.result().numpy())

plt.figure(figsize=(15, 10))
plt.subplot(241)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(242)
plt.title('Testing Label')
plt.imshow(ground_truth, cmap='gray')
plt.subplot(243)
plt.title('Prediction on test image')
plt.imshow(prediction[0,:,:,0])
plt.subplot(244)
plt.title('Prediction on test image w/th')
plt.imshow(predicted_img_th, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Mean IoU = 1.0
